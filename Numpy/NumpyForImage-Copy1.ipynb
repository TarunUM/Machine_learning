# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Pillow
# Out:
# ...
#      ---------------------------------------- 2.5/2.5 MB 3.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 3.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 965.4/965.4 kB 5.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 161.3/161.3 kB 4.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.4/55.4 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB 5.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("doctor-strange.jpg")

# %%
#converting Image to arrays to work on it
arr = np.array(pil)

# %%
arr.shape
# Out:
# (1000, 1500, 3)

# %%
#for printing Image using Arrays
plt.imshow(pil)

# %%
#calour mapping i.e. representing image in grey Scale(black to white)
plt.imshow(red, cmap="gray")

# %%
#red = only 1st dimesional array will be displayed (R=0, G=1 ,B=2)
red = arr[:, :, 0]

# %%
plt.imshow(red)

# %%
#slicing = displaying with specific amount of arrays from whole
slicing = arr[20:400, 630:880]

# %%
plt.imshow(slicing)

# %%
work = arr.copy()

# %%
work.shape
# Out:
# (1000, 1500, 3)

# %%
#decolouring red(0) and blue(2) to zero 
work[:, :, [0,2]] = 0

# %%
plt.imshow(work)

# %%
arr
# Out:
# array([[[236, 209, 190],
#         [236, 209, 190],
#         [236, 209, 190],
#         ...,
#         [239, 217, 204],
#         [239, 217, 204],
#         [239, 217, 204]],
#
#        [[232, 205, 186],
#         [232, 205, 186],
#         [232, 205, 186],
#         ...,
#         [239, 217, 204],
#         [239, 217, 204],
#         [239, 217, 204]],
#
#        [[233, 206, 187],
#         [233, 206, 187],
#         [233, 206, 187],
#         ...,
#         [239, 217, 204],
#         [239, 217, 204],
#         [238, 216, 203]],
#
#        ...,
#
#        [[ 30,   5,   9],
#         [ 30,   5,   8],
#         [ 30,   5,   9],
#         ...,
#         [ 23,  18,   0],
#         [ 24,  17,   0],
#         [ 23,  18,   0]],
#
#        [[111,   9,   5],
#         [111,   9,   4],
#         [111,   9,   5],
#         ...,
#         [ 47,  44,  27],
#         [ 49,  43,  27],
#         [ 47,  44,  25]],
#
#        [[188,  50,  40],
#         [188,  50,  40],
#         [188,  50,  40],
# ...

# %%
meaning = arr.mean(axis=2)

# %%
#multicolour grayscale
plt.imshow(meaning)

# %%
#in B/W grayscale
plt.imshow(meaning, cmap="gray")
